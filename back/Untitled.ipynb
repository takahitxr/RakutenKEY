# %%
import requests
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import json
import datetime

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_experimental_option('excludeSwitches', ['enable-logging'])
options.use_chromium = True


browser = webdriver.Chrome(ChromeDriverManager().install(), options=options)
browser.get('https://search.rakuten.co.jp/search/keyword/')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\txrkc\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\txrkc\AppData\Local\Temp/ipykernel_1352/3409238463.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install(), options=options)

# %%
req1 = browser.find_elements_by_class_name("kWdWrd")
req2 = browser.find_elements_by_class_name("kWdRestWrd")
# Out:
# C:\Users\txrkc\AppData\Local\Temp/ipykernel_1352/2968663592.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   req1 = browser.find_elements_by_class_name("kWdWrd")
# C:\Users\txrkc\AppData\Local\Temp/ipykernel_1352/2968663592.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   req2 = browser.find_elements_by_class_name("kWdRestWrd")

# %%
kyou = datetime.date.today()

# %%
req1.extend(req2)

# %%
results = [
        {
        "keyword": key.text,
        "rank": a + 1,
        }for a, key in enumerate(req1)
    ]

# %%
# Out:
# 2022-06-19

# %%
json.dumps(results, ensure_ascii=False)
# Out:
# '[{"keyword": "マスク", "rank": 1}, {"keyword": "父の日ギフト", "rank": 2}, {"keyword": "送料無料", "rank": 3}, {"keyword": "ワンピース", "rank": 4}, {"keyword": "サンダル", "rank": 5}, {"keyword": "tシャツ", "rank": 6}, {"keyword": "ラッシュガード", "rank": 7}, {"keyword": "ふるさと納税 訳あり", "rank": 8}, {"keyword": "うなぎ", "rank": 9}, {"keyword": "水着", "rank": 10}, {"keyword": "sale", "rank": 11}, {"keyword": "プロテイン", "rank": 12}, {"keyword": "スマートウォッチ", "rank": 13}, {"keyword": "扇風機", "rank": 14}, {"keyword": "ノースフェイス", "rank": 15}, {"keyword": "スニーカー", "rank": 16}, {"keyword": "靴下", "rank": 17}, {"keyword": "炭酸水", "rank": 18}, {"keyword": "リュック", "rank": 19}, {"keyword": "ふるさと納税 うなぎ", "rank": 20}, {"keyword": "水", "rank": 21}, {"keyword": "トイレットペーパー", "rank": 22}, {"keyword": "タオル", "rank": 23}, {"keyword": "財布", "rank": 24}, {"keyword": "ニューバランス", "rank": 25}, {"keyword": "サーキュレーター", "rank": 26}, {"keyword": "アウトレット", "rank": 27}, {"keyword": "米", "rank": 28}, {"keyword": "シャンプー", "rank": 29}, {"keyword": "セール", "rank": 30}, {"keyword": "バッグ", "rank": 31}, {"keyword": "日傘", "rank": 32}, {"keyword": "ワイヤレスイヤホン", "rank": 33}, {"keyword": "プールバッグ", "rank": 34}, {"keyword": "モバイルバッテリー", "rank": 35}, {"keyword": "傘", "rank": 36}, {"keyword": "父の日 ビール", "rank": 37}, {"keyword": "パンツ", "rank": 38}, {"keyword": "水筒", "rank": 39}, {"keyword": "bts", "rank": 40}, {"keyword": "ビール", "rank": 41}, {"keyword": "ポロシャツ", "rank": 42}, {"keyword": "カーディガン", "rank": 43}, {"keyword": "ナイトブラ", "rank": 44}, {"keyword": "トートバッグ", "rank": 45}, {"keyword": "コーヒー", "rank": 46}, {"keyword": "ピアス", "rank": 47}, {"keyword":