# %%
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import time
import datetime
import gspread
import json

scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('angular-spider-312007-557058f7d529.json', scope)
gc = gspread.authorize(credentials)

SPREADSHEET_KEY = '1DNx5LcmrJyoxLKJM6qhasfM4CxlWOG9Yn1xmMUe2aDo'
sheet = gc.open_by_key(SPREADSHEET_KEY).worksheet('シート1')

# %%
data = sheet.get_all_values()
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df[:3]
# Out:
#          Date    1       2      3        4     5     6   7    8         9  \
# 0  2022/06/20  マスク  父の日ギフト  ワンピース  ラッシュガード  tシャツ  サンダル  水着  うなぎ  スマートウォッチ
# 1  2022/06/20  マスク  父の日ギフト  ワンピース  ラッシュガード  tシャツ  サンダル  水着  うなぎ  スマートウォッチ
#
#    ...     991      992       993       994  995      996         997 998  \
# 0  ...  ジルサンダー  レジャーシート  クッションフロア  メンズ サンダル  レジン  カフェカーテン  カーテン 4枚セット   鍋
# 1  ...  ジルサンダー  レジャーシート  クッションフロア  メンズ サンダル  レジン  カフェカーテン  カーテン 4枚セット   鍋
#
#      999    1000
# 0  バスケット  遮光カーテン
# 1  バスケット  遮光カーテン
#
# [2 rows x 1001 columns]

# %%
def keycheck():

    url = "https://search.rakuten.co.jp/search/keyword/"

    options = Options()
    #options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--incognito')

    browser = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)

    browser.get(url)
    browser.implicitly_wait(20)

    toprank = browser.find_elements_by_class_name("kWdWrd")
    nextrank = browser.find_elements_by_class_name("kWdRestWrd")
    toprank.extend(nextrank)

    results = {f"{i + 1}": key.text for i, key in enumerate(toprank)}
    
    browser.close()
    return results

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('angular-spider-312007-557058f7d529.json', scope)
gc = gspread.authorize(credentials)

SPREADSHEET_KEY = '1DNx5LcmrJyoxLKJM6qhasfM4CxlWOG9Yn1xmMUe2aDo'
sheet = gc.open_by_key(SPREADSHEET_KEY).worksheet('シート1')

data = sheet.get_all_values()
df = pd.DataFrame(data[1:], columns=data[0])
df = df.set_index("Date")

# %%
df
# Out:
#               1       2       3        4        5        6     7    8  \
# Date
# 2022/06/20  マスク  父の日ギフト   ワンピース  ラッシュガード     tシャツ     サンダル    水着  うなぎ
# 2022/06/21  マスク  父の日ギフト   ワンピース     tシャツ  ラッシュガード     サンダル    水着  うなぎ
# 2022/06/22  マスク  父の日ギフト   ワンピース     tシャツ  ラッシュガード     サンダル   扇風機   水着
# 2022/06/23  マスク   ワンピース  父の日ギフト     tシャツ      扇風機  ラッシュガード  サンダル   水着
#
#                      9          10  ...       991      992       993  \
# Date                                ...
# 2022/06/20    スマートウォッチ  ふるさと納税 訳あり  ...    ジルサンダー  レジャーシート  クッションフロア
# 2022/06/21         扇風機  ふるさと納税 訳あり  ...     バスケット      レトロ     ぬいぐるみ
# 2022/06/22         うなぎ  ふるさと納税 訳あり  ...  ホエイプロテイン    ネイル工房     アイマスク
# 2022/06/23  ふるさと納税 訳あり         うなぎ  ...      vans  マルチビタミン  シリコンモールド
#
#                          994         995      996         997     998  \
# Date
# 2022/06/20          メンズ サンダル         レジン  カフェカーテン  カーテン 4枚セット       鍋
# 2022/06/21  ふるさと納税 トイレットペーパー  ショルダーストラップ   テレビボード          紅茶      喪服
# 2022/06/22              ジュース   東京リベンジャーズ   コラントッテ    玩具 大人 女性  ジルサンダー
# 2022/06/23         東京リベンジャーズ       延長コード   マヌカハニー           黒    ステテコ
#
#                     999        1000
# Date
# 2022/06/20        バスケット      遮光カーテン
# 2022/06/21     無くなり次第終了      カーゴパンツ
# 2022/06/22  クーラーボックス 小型      ノンワイヤー
# 2022/06/23     bts アルバム  カーテン 4枚セット
#
# [4 rows x 1000 columns]

# %%
today = "2022/06/20"

# %%
df
# Out:
#               1       2      3        4     5     6   7    8         9  \
# Date
# 2022/06/20  マスク  父の日ギフト  ワンピース  ラッシュガード  tシャツ  サンダル  水着  うなぎ  スマートウォッチ
#
#                     10  ...     991      992       993       994  995  \
# Date                    ...
# 2022/06/20  ふるさと納税 訳あり  ...  ジルサンダー  レジャーシート  クッションフロア  メンズ サンダル  レジン
#
#                 996         997 998    999    1000
# Date
# 2022/06/20  カフェカーテン  カーテン 4枚セット   鍋  バスケット  遮光カーテン
#
# [1 rows x 1000 columns]

# %%
for idx in range(len(df.columns)):
    print(df.values[0][idx])

# %%
dftoday = df.loc[["2022/06/20"]].values[0]

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('angular-spider-312007-557058f7d529.json', scope)
gc = gspread.authorize(credentials)

SPREADSHEET_KEY = '1DNx5LcmrJyoxLKJM6qhasfM4CxlWOG9Yn1xmMUe2aDo'
sheet = gc.open_by_key(SPREADSHEET_KEY).worksheet('シート1')

data = sheet.get_all_values()
df = pd.DataFrame(data[1:], columns=data[0])
df = df.set_index("Date")

# %%
df.index[0]
# Out:
# '2022/06/20'

# %%
for searchday in df2:
    if len(df2[df2[searchday] == f"{selectkey}"].index) > 0:
        i = df2[df2[searchday] == f"{selectkey}"].index[0]
        ranklist.append(i)
    else:
        ranklist.append(0)

# %%
for searchday in df2:
    if len(df2[df2[searchday] == f"{selectkey}"].index) > 0:
        i = df2[df2[searchday] == f"{selectkey}"].index[0]
        ranklist.append(i)
    else:
        ranklist.append(0)

# %%
selectkey = "扇風機"
ranklist = []
df2 = df.T

# %%
ranklist
# Out:
# ['16', '9', '7', '5']

# %% [markdown]
# ranklist = [1,1]

# %%
df2
# Out:
# Date  2022/06/20 2022/06/21   2022/06/22  2022/06/23
# 1            マスク        マスク          マスク         マスク
# 2         父の日ギフト     父の日ギフト       父の日ギフト       ワンピース
# 3          ワンピース      ワンピース        ワンピース      父の日ギフト
# 4        ラッシュガード       tシャツ         tシャツ        tシャツ
# 5           tシャツ    ラッシュガード      ラッシュガード         扇風機
# ...          ...        ...          ...         ...
# 996      カフェカーテン     テレビボード       コラントッテ      マヌカハニー
# 997   カーテン 4枚セット         紅茶     玩具 大人 女性           黒
# 998            鍋         喪服       ジルサンダー        ステテコ
# 999        バスケット   無くなり次第終了  クーラーボックス 小型    bts アルバム
# 1000      遮光カーテン     カーゴパンツ       ノンワイヤー  カーテン 4枚セット
#
# [1000 rows x 4 columns]

# %%
df2[df2[searchday] == "扇風機"]
# Out:
# Date 2022/06/20 2022/06/21 2022/06/22 2022/06/23
# 5          tシャツ    ラッシュガード    ラッシュガード        扇風機

# %%
df[df2[searchday].str.contains("父の日")].index[0]
# Out:
# C:\Users\txrkc\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-43-2dae6054e52d> in <module>
# ----> 1 df[df2[searchday].str.contains("父の日")].index[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2947         # check_bool_indexer will throw exception if Series key cannot
#    2948         # be reindexed to match DataFrame rows
# -> 2949         key = check_bool_indexer(self.index, key)
#    2950         indexer = key.nonzero()[0]
#    2951         return self._take_with_is_copy(indexer, axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2181         if mask.any():
#    2182             raise IndexingError(
# -> 2183                 "Unalignable boolean Series provided as "
#    2184                 "indexer (index of the boolean Series and of "
#    2185                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
alist = df2[df2[searchday].str.contains('父')].index

# %%
len(df.columns[df.loc[searchday] == "父の日"])
# Out:
# 0

# %%
testlist = []

# %%
testlist
# Out:
# ['父の日ギフト',
#  '父の日 ビール',
#  '父の日 プレゼント 実用的',
#  '父の日プレゼント',
#  '父の日 食べ物',
#  '父の日 スイーツ',
#  '父の日 うなぎ',
#  'うなぎ 父の日',
#  '父の日 お酒',
#  'ビール 父の日',
#  '父の日 海鮮',
#  '父の日 焼酎',
#  '父の日 間に合う',
#  '父の日ギフト ビール',
#  '父の日 花',
#  '父の日ギフト スイーツ',
#  '父の日 おつまみセット']

# %%
selected_date=["2022-06-20", "2022-06-22"]

date_str_list = pd.date_range(selected_date[0], selected_date[1])

# %%
date_str_list.strftime('%Y/%m/%d')[0]
# Out:
# '2022/06/20'

# %%
df.loc["2022/06/22"]
# Out:
# 1            マスク
# 2         父の日ギフト
# 3          ワンピース
# 4           tシャツ
# 5        ラッシュガード
#           ...
# 996       テレビボード
# 997           紅茶
# 998           喪服
# 999     無くなり次第終了
# 1000      カーゴパンツ
# Name: 2022/06/22, Length: 1000, dtype: object

# %%
ranklist.append(date_str_list.strftime('%Y/%m/%d'))

# %%
ranklist
# Out:
# ['1',
#  '1',
#  '1',
#  Index(['2022/06/20', '2022/06/21', '2022/06/22'], dtype='object')]

# %%
data1 = pd.DataFrame(ranklist, columns=["マスク"])
data2 = pd.DataFrame(date_str_list.strftime('%Y/%m/%d'), columns=["date"])
data3 = pd.concat([data1,data2], axis=1)

# %%
data3 = pd.concat([data1,data2], axis=1)

# %%
for i in date_str_list.strftime('%Y/%m/%d'):
    ranklist.append(df.columns[df.loc[i] == "マスク"][0])

# %%
ranklist
# Out:
# ['1', '1', '1']

# %%
ranklist = []

# %%
data3["key"] = "key"

# %%
data3
# Out:
#   マスク        date  key
# 0   1  2022/06/20  key
# 1   1  2022/06/21  key
# 2   1  2022/06/22  key
